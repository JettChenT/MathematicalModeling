# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('./data/processed/main.csv')

# %%
data.head()
# Out:
#    Zipcode  bike_rental  parking  public_transport  schools  shop  \
# 0    50309           24        2               196        0   100
# 1    50311            8        0                46        0    34
# 2    50312            2        2                52        0    44
# 3    50314            4        0                92        0     6
# 4    50315            2        0                 2        4    28
#
#    population_density        city
# 0              1914.0  Des Moines
# 1              6011.0  Des Moines
# 2              2701.0  Des Moines
# 3              5014.0  Des Moines
# 4              3578.0  Des Moines

# %%
numerical_cat = ['bike_rental', 'parking', 'public_transport', 'schools', 'shop', 'population_density']

# %% [markdown]
# # Data normalization

# %%
df_norm = data.copy()

# %%
# Logarithmic normalization of the 'shop' row
df_norm['shop'] = np.clip(np.log(df_norm['shop'],), -1, float('inf'))
# Out:
# /Users/jettchen/anaconda3/envs/himcm/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.displot(df_norm, x='shop')

# %%
# Scaling normalization
for cat in numerical_cat:
    df_norm[cat] = (df_norm[cat] - df_norm[cat].min()) / (df_norm[cat].max() - df_norm[cat].min())

# %%
print(df_norm['shop'].min())
print(df_norm['shop'].max())
# Out:
# 0.0
# 1.0

# %%
g = sns.PairGrid(df_norm[['bike_rental', 'population_density', 'shop', 'schools', 'public_transport']])
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %% [markdown]
# ## Get the weights of the model

# %%
correlation = data.corr()
correlation.head()
# Out:
#                    Zipcode  bike_rental   parking  public_transport   schools  \
# Zipcode           1.000000    -0.249479  0.360667         -0.179097 -0.008904
# bike_rental      -0.249479     1.000000 -0.082611          0.672247  0.517120
# parking           0.360667    -0.082611  1.000000         -0.147453 -0.095865
# public_transport -0.179097     0.672247 -0.147453          1.000000  0.718554
# schools          -0.008904     0.517120 -0.095865          0.718554  1.000000
#
#                       shop  population_density
# Zipcode           0.400439           -0.125699
# bike_rental       0.195414            0.414713
# parking           0.135601            0.068508
# public_transport  0.048300            0.020894
# schools           0.065067            0.004415

# %%
correlation = df_norm.corr()
correlation.head()
# Out:
#                    Zipcode  bike_rental   parking  public_transport   schools  \
# Zipcode           1.000000    -0.249479  0.360667         -0.179097 -0.008904
# bike_rental      -0.249479     1.000000 -0.082611          0.672247  0.517120
# parking           0.360667    -0.082611  1.000000         -0.147453 -0.095865
# public_transport -0.179097     0.672247 -0.147453          1.000000  0.718554
# schools          -0.008904     0.517120 -0.095865          0.718554  1.000000
#
#                       shop  population_density
# Zipcode           0.260729           -0.125699
# bike_rental       0.388773            0.414713
# parking           0.214599            0.068508
# public_transport  0.285456            0.020894
# schools           0.242724            0.004415

# %%
weights = correlation['bike_rental'][['parking', 'public_transport', 'schools', 'shop', 'population_density']]
weights
# Out:
# parking              -0.082611
# public_transport      0.672247
# schools               0.517120
# shop                  0.388773
# population_density    0.414713
# Name: bike_rental, dtype: float64

# %%
weights_np = weights.to_numpy()
pcols = ['parking', 'public_transport', 'schools', 'shop', 'population_density']
df_norm['score'] = df_norm.apply(lambda x: np.dot(weights_np, x[pcols].to_numpy()), axis=1)

# %%
df_norm['score'] = (df_norm['score'] - np.min(df_norm['score'])) / (np.max(df_norm['score']) - np.min(df_norm['score']))
sns.displot(df_norm, x='score', kde=True)

# %%
sns.scatterplot(x='score', y='bike_rental', data=df_norm)
# Out:
# <AxesSubplot:xlabel='score', ylabel='bike_rental'>

# %%
df_norm['relative_score'] = df_norm['score'] - df_norm['bike_rental']
df_norm['relative_score'] = (df_norm['relative_score']- df_norm['relative_score'].min()) / (df_norm['relative_score'].max() - df_norm['relative_score'].min())

# %%
sns.displot(df_norm, x='relative_score', kde=True)

# %% [markdown]
# # Results

# %%
cities = ['Chicago', 'Des Moines', 'Denver']
res = dict()

for city in cities:
    res[city] = df_norm[df_norm['city']==city].sort_values(by=['relative_score'], ascending=False)[['Zipcode', 'relative_score']]
    res[city].to_csv(f'./data/results/{city}_relative_rank.csv', index=False)

# %% [markdown]
# ## Zip Code Ranking based on relative score for each of the cities

# %%
res['Chicago'].head()
# Out:
#     Zipcode  relative_score
# 25    60620        1.000000
# 40    60638        0.827623
# 34    60630        0.814919
# 57    60660        0.769253
# 32    60628        0.759232

# %%
res['Denver'].head()
# Out:
#     Zipcode  relative_score
# 64    80204        0.819499
# 68    80211        0.774827
# 65    80205        0.769014
# 62    80202        0.691926
# 67    80210        0.686914

# %%
res['Des Moines'].head()
# Out:
#    Zipcode  relative_score
# 4    50315        0.603952
# 2    50312        0.592437
# 3    50314        0.536949
# 1    50311        0.536634
# 0    50309        0.372503

# %%
len(df_norm) - len(df_norm[df_norm['city']=='Chicago'])
# Out:
# 20

# %% [markdown]
# # Publishing

# %%
weights
# Out:
# parking              -0.082611
# public_transport      0.672247
# schools               0.517120
# shop                  0.388773
# population_density    0.414713
# Name: bike_rental, dtype: float64
